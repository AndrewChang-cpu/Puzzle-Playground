# %% [markdown]
# unpacking a slice in assignment

# %%
a = [1, 2, 3, 4, 5]
x, *a[2:5], y = a
print(x, y, a)
# Out:
# 1 5 [1, 2, 2, 3, 4]

# %%
a = [1, 2, 3, 4, 5, 6]
x, *a[2:5], y = a
print(x, y, a)
# Out:
# 1 6 [1, 2, 2, 3, 4, 5, 6]
